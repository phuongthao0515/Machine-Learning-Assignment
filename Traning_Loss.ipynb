# %% [markdown]
# <a href="https://colab.research.google.com/github/phuongthao0515/Machine-Learning-Assignment/blob/main/Traning_Loss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Metrics Plot
# - Since the training spanned multiple sessions,we can't directly use the history object for plots. The loss values werer saved in the text files and then plotted afterwards. The following image was created using the script at the bottom.
# - As we can see, the last model checkpoint has the best validation loss.

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
train_losses = []
val_losses = []
path_exp = "/content/epochs/"
# epochs = os.listdir(path_exp)
# epochs.sort()
with open(path_exp + "epoch0" + "/train_loss.txt") as f:
     epoch_losses = f.readlines()
     train_losses += epoch_losses

with open(path_exp+ "epoch0" +"/val_loss.txt") as f:
    epoch_losses = f.readlines()
    val_losses += epoch_losses

with open(path_exp + "epoch1" + "/train_loss.txt") as f:
     epoch_losses = f.readlines()
     train_losses += epoch_losses

with open(path_exp+ "epoch1" +"/val_loss.txt") as f:
    epoch_losses = f.readlines()
    val_losses += epoch_losses

# %%
steps = np.arange(1,len(val_losses)+1)*7200
val_losses = [float(l.strip()) for l in val_losses]
train_losses = [float(l.strip()) for l in train_losses]

# Plotting the losses
plt.figure(figsize=(10, 6))
plt.plot(steps, train_losses, label='Train Loss', marker='o')
plt.plot(steps, val_losses, label='Validation Loss', marker='o')

# Adding title and labels
plt.title('Training and Validation Loss')
plt.xlabel('Steps')
plt.ylabel('Loss')

# Adding legend
plt.legend()

# Show the plot
plt.show()
